# %% [markdown]
# # Testing OSKAR and CASA Python Distributions

# %%
import oskar
import numpy
import matplotlib

# %%
params = {
    "simulator": {
        "use_gpus": False
    },
    "observation" : {
        "num_channels": 1,
        "start_frequency_hz": 177.408e6,
        "frequency_inc_hz": 20e6,
        "phase_centre_ra_deg": 0.0,
        "phase_centre_dec_deg": -27.0,
        "num_time_steps": 8,
        "start_time_utc": "2025-03-03 05:30:00.00",
        "length": "00:02:00.000"
    },
    "telescope": {
        "input_directory": "../oskar_run_stage/telescope_model_AAstar"
    },
    "interferometer": {
        "oskar_vis_filename": "output/vis.vis",
        "ms_filename": "output/sim.ms",
        "channel_bandwidth_hz": 1e6,
        "time_average_sec": 8
    },
    "sky": {
        "oskar_sky_model/file": "./regrid/osm_output/gaussian_zenith_osm/no.1_177.408MHz.osm"
    }
}

settings = oskar.SettingsTree("oskar_sim_interferometer")
settings.from_dict(params)
settings["simulator/double_precision"] = True

# %%
ini_settings = oskar.SettingsTree("oskar_sim_interferometer", "test_intif_inis/test_intif_gen_bash.ini")
ini_settings["observation/start_frequency_hz"] = 177.408e6
ini_settings["sky/oskar_sky_model/file"] = "./regrid/osm_output/gaussian_zenith_osm/no.1_177.408MHz.osm"

img_settings = oskar.SettingsTree("oskar_imager", "test_intif_inis/test_img_gen_bash.ini")

# %%
sim = oskar.Interferometer(settings=ini_settings)
sim.run()
# Out:
# W|
# W|== WARNING: Sky model contains no sources.
# W|
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 2
#       1 sim = oskar.Interferometer(settings=ini_settings)
# ----> 2 sim.run()
#
# File /usr/local/lib/python3.12/dist-packages/oskar/interferometer.py:268, in Interferometer.run(self)
#     260 """Runs the interferometer simulator.
#     261
#     262 The method process_block() is called for each simulated visibility
#    (...)
#     265 visibilities differently.
#     266 """
#     267 self.capsule_ensure()
# --> 268 self.check_init()
#     269 self.reset_work_unit_index()
#     270 num_threads = self.num_devices + 1
#
# File /usr/local/lib/python3.12/dist-packages/oskar/interferometer.py:142, in Interferometer.check_init(self)
#     140 if self._settings is not None:
#     141     if not self._sky_model_set:
# --> 142         self.set_sky_model(self._settings.to_sky())
#     143     if not self._telescope_model_set:
#     144         self.set_telescope_model(self._settings.to_telescope())
#
# File /usr/local/lib/python3.12/dist-packages/oskar/settings_tree.py:183, in SettingsTree.to_sky(self)
#     177 """Returns a new sky model from the current settings.
#     178
#     179 Returns:
#     180     oskar.Sky: A configured sky model.
#     181 """
#     182 sky = Sky()
# --> 183 sky.capsule = _apps_lib.settings_to_sky(self._capsule)
#     184 return sky
#
# RuntimeError: oskar_settings_to_sky() failed with code -2 (file I/O error).
